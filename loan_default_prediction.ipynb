# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('Loan_default_kaggle.csv')
df.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# ...

# %%
#finding shape of the data
df.shape
# Out:
# (255347, 18)

# %%
df.columns
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner',
#        'Default'],
#       dtype='object')

# %%
# droping unwanted columns
df1 = df.drop(['LoanID', 'Education'], axis = 1)
df1.head(60)
# Out:
#     Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0    56   85994       50587          520              80               4
# 1    69   50432      124440          458              15               1
# 2    46   84208      129188          451              26               3
# 3    32   31713       44799          743               0               3
# 4    60   20437        9139          633               8               4
# 5    25   90298       90448          720              18               2
# 6    38  111188      177025          429              80               1
# 7    56  126802      155511          531              67               4
# 8    36   42053       92357          827              83               1
# 9    40  132784      228510          480             114               4
# 10   28  140466      163781          652              94               2
# 11   28  149227      139759          375              56               3
# ...

# %%
df1.shape
# Out:
# (255347, 16)

# %%
# using sklearn label encoder mapping (0,1) HasMortgage, HasDependents, HasCoSigner
encoder = LabelEncoder()
df1['HasMortgage'] = encoder.fit_transform(df1['HasMortgage'])
df1['HasDependents'] = encoder.fit_transform(df1['HasDependents'])
df1['HasCoSigner'] = encoder.fit_transform(df1['HasCoSigner'])
df1['EmploymentType'] = encoder.fit_transform(df1['EmploymentType'])
df1['MaritalStatus'] = encoder.fit_transform(df1['MaritalStatus'])
df1['LoanPurpose'] = encoder.fit_transform(df1['LoanPurpose'])

# %%
df1.head(15)
# Out:
#     Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0    56   85994       50587          520              80               4
# 1    69   50432      124440          458              15               1
# 2    46   84208      129188          451              26               3
# 3    32   31713       44799          743               0               3
# 4    60   20437        9139          633               8               4
# 5    25   90298       90448          720              18               2
# 6    38  111188      177025          429              80               1
# 7    56  126802      155511          531              67               4
# 8    36   42053       92357          827              83               1
# 9    40  132784      228510          480             114               4
# 10   28  140466      163781          652              94               2
# 11   28  149227      139759          375              56               3
# ...

# %%
df.HasCoSigner.isnull().sum()
# Out:
# np.int64(0)

# %%
df1.shape
# Out:
# (255347, 16)

# %%
X = df1.drop('Default', axis = 1)
X.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  EmploymentType  MaritalStatus  \
# 0         15.23        36      0.44               0              0
# 1          4.81        60      0.68               0              1
# 2         21.17        24      0.31               3              0
# 3          7.07        24      0.23               0              1
# 4          6.51        48      0.73               3              0
#
#    HasMortgage  HasDependents  LoanPurpose  HasCoSigner
# 0            1              1            4            1
# ...

# %%
y = df1['Default']
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Default, dtype: int64

# %%
# train test splitting 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=None, shuffle=False )

# %%
X_train.shape
# Out:
# (204277, 15)

# %%
X_test.shape
# Out:
# (51070, 15)

# %%
 # importing Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pre = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.8863520657920502

# %%
#model saving
import pickle
with open('loan_default_model.pkl', 'wb') as f:
    pickle.dump(model,f)

# %%
# one hot encoding for EmploymentType, MaritalStatus, LoanPurpose
# X.EmploymentType.unique()

# %%
# ohe = OneHotEncoder ( drop='first', handle_unknown='ignore', sparse_output=False).set_output(transform='pandas')
# ohe_EmploymentType =ohe.fit_transform(X[['EmploymentType']])

# %%
# ohe_EmploymentType

# %%
# X1 = pd.concat([X,ohe_EmploymentType], axis = 1).drop(columns= ['EmploymentType'])

# %%
# X1.head()

# %%
# X1.shape

# %%
# X1.MaritalStatus.unique()

# %%
# ohe=OneHotEncoder(drop='first',handle_unknown='ignore',sparse_output=False).set_output(transform='pandas')
# ohe_MaritalStatus = ohe.fit_transform(X1[['MaritalStatus']])

# %%
# X2 = pd.concat([X1,ohe_MaritalStatus], axis=1).drop(columns='MaritalStatus')

# %%
# X2.head()

# %%
# X2.LoanPurpose.unique()

# %%
# ohe = OneHotEncoder(drop='first',handle_unknown='ignore',sparse_output=False).set_output(transform='pandas')
# ohe_LoanPurpose = ohe.fit_transform(X2[['LoanPurpose']])

# %%
# X3 = pd.concat([X2,ohe_LoanPurpose],axis=1).drop(columns='LoanPurpose')

# %%
# X3.head()

# %%
# X_fin = X3
# X_fin.shape

# %%
# y.head()

# %%
# train test splitting 
# from sklearn.model_selection import train_test_split
# X_train,X_test,y_train,y_test = train_test_split(X_fin, y, test_size=0.2, random_state=None, shuffle=False )

# %%
# X_train.head()

# %%
# X_train.shape

# %%
# y_test.shape

# %%
 # importing Random Forest Classifier
# from sklearn.ensemble import RandomForestClassifier
# model = RandomForestClassifier()

# %%
# model.fit(X_train,y_train)

# %%
# y_pre = model.predict(X_test)

# %%
# y_pre

# %%
# model.score(X_test,y_pre)

# %%
# Evaluating the model
# from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score
# acc = accuracy_score(y_test,y_pre)
# prec = precision_score(y_test,y_pre)
# rec = recall_score(y_test,y_pre)
# f1 = f1_score(y_test,y_pre)
# roc = roc_auc_score(y_test,y_pre)

# %%
# print("The accuracy of the Random forest is:",acc)
# print("The precision of the Random forest is:",prec)
# print("The recall of the Random forest is:",rec)
# print("The f1 of the Random forest is:",f1)
# print("The roc_auc of the Random forest is:",roc)

# %%
# import joblib

# # Save the model
# joblib.dump(model, 'loan_default_model.joblib')
# print("Model saved successfully!")

# # Load the model
# loaded_model = joblib.load('loan_default_model.joblib')
# print("Model loaded successfully!")
